# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv('decade-2000s-songs.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                        track  \
# 0           0             0               Where'd You Go
# 1           1             1                     Hands Up
# 2           3             3          This Is Why I'm Hot
# 3           4             4  Eclipse (Corona Of The Sun)
# 4           5             5                   Need U Bad
#
#                              artist                                   uri  \
# 0  Fort Minor Featuring Holly Brook  spotify:track:7pAT4dOUzjq8Ziap5ShIqC
# 1     Lloyd Banks Featuring 50 Cent  spotify:track:2GlhJyZRWP3MnSXOvnovIa
# 2                              Mims  spotify:track:0AA6zq5ArZ1sSH7VIMi4NK
# 3                         Dol Ammad  spotify:track:2nu1wORaGp31BD50qgkmw9
# 4                  Jazmine Sullivan  spotify:track:0Ri0LzOMJmqi9HGZE5cRYV
#
#    danceability  energy  key  loudness  mode  ...  instrumentalness  liveness  \
# 0         0.684   0.819    1    -3.309     0  ...           0.00197     0.113
# 1         0.799   0.878    1    -2.282     1  ...           0.00000     0.510
# 2         0.621   0.600    8    -6.349     1  ...           0.00000     0.495
# 3         0.395   0.820   10    -7.543     0  ...           0.36100     0.108
# 4         0.529   0.659    7    -5.318     1  ...           0.00000     0.114
#
#    valence    tempo  duration_ms  time_signature  chorus_hit  sections  \
# 0    0.250  179.999       231867               4    21.90591        12
# 1    0.594   95.000       240213               4    30.75746        11
# 2    0.485   80.021       253707               4    36.65840        12
# 3    0.106  179.980       266613               4    36.05760        12
# 4    0.360  138.196       257427               4    75.70191         8
#
#    target                                             lyrics
# 0       1  [Chorus: Skylar Grey]\nWhere'd you go? I miss ...
# 1       1  [Intro]\nPut 'em up\nPut 'em up, put 'em up, p...
# 2       1  [Chorus]\nThis is why I'm hot (Hot!), this is ...
# 3       0  Give up! Give in!\nGive up to the light\nRespe...
# 4       1  Oh!\nAy baby, weh you ah deal with?\nWe come t...
#
# [5 rows x 22 columns]

# %%
#how many rows in dataset

number_of_rows = len(df.index)
print(number_of_rows)
# Out:
# 4791

# %%
df['track'].unique()
# Out:
# array(["Where'd You Go", 'Hands Up', "This Is Why I'm Hot", ...,
#        "There's a Fine, Fine Line", 'My Old Friend', "Sittin' Sidewayz"],
#       dtype=object)

# %%
#number of unique tracks
len(df['track'].unique())

#The output is 11240 ,expecting 12270 rows based on rows in csv
#need to investigate why less tracks,duplicate tracks present?
# Out:
# 4566

# %%
df['artist'].unique()
# Out:
# array(['Fort Minor Featuring Holly Brook',
#        'Lloyd Banks Featuring 50 Cent', 'Mims', ...,
#        'Plies Featuring Chris J', "Stephanie D'Abruzzo",
#        'Paul Wall Featuring Big Pokey'], dtype=object)

# %%
#number of unique tracks
len(df['artist'].unique())
# Out:
# 2403

# %%
df.dropna()
# Out:
#       Unnamed: 0  Unnamed: 0.1                        track  \
# 0              0             0               Where'd You Go
# 1              1             1                     Hands Up
# 2              3             3          This Is Why I'm Hot
# 3              4             4  Eclipse (Corona Of The Sun)
# 4              5             5                   Need U Bad
# ...          ...           ...                          ...
# 4786        1995          1995                      Imagine
# 4787        1996          1996                     Float On
# 4788        1997          1997    There's a Fine, Fine Line
# 4789        1998          1998                My Old Friend
# 4790        1999          1999             Sittin' Sidewayz
#
#                                 artist                                   uri  \
# 0     Fort Minor Featuring Holly Brook  spotify:track:7pAT4dOUzjq8Ziap5ShIqC
# 1        Lloyd Banks Featuring 50 Cent  spotify:track:2GlhJyZRWP3MnSXOvnovIa
# 2                                 Mims  spotify:track:0AA6zq5ArZ1sSH7VIMi4NK
# 3                            Dol Ammad  spotify:track:2nu1wORaGp31BD50qgkmw9
# 4                     Jazmine Sullivan  spotify:track:0Ri0LzOMJmqi9HGZE5cRYV
# ...                                ...                                   ...
# 4786                              DJ D  spotify:track:5MT5YaAB4aaBOxQsU2wCUW
# 4787                      Modest Mouse  spotify:track:2lwwrWVKdf3LR9lbbhnr6R
# 4788               Stephanie D'Abruzzo  spotify:track:2W7wqrmruKE07zZCg8rSdm
# 4789                        Tim McGraw  spotify:track:2AbgjLSmW8l5XaaR4nQE3w
# 4790     Paul Wall Featuring Big Pokey  spotify:track:24PWKmemCvqfyVXODhoKHW
#
#       danceability  energy  key  loudness  mode  ...  instrumentalness  \
# 0            0.684   0.819    1    -3.309     0  ...          0.001970
# 1            0.799   0.878    1    -2.282     1  ...          0.000000
# 2            0.621   0.600    8    -6.349     1  ...          0.000000
# 3            0.395   0.820   10    -7.543     0  ...          0.361000
# 4            0.529   0.659    7    -5.318     1  ...          0.000000
# ...            ...     ...  ...       ...   ...  ...               ...
# 4786         0.536   0.846    4    -6.683     1  ...          0.120000
# 4787         0.649   0.888    6    -4.807     1  ...          0.000002
# 4788         0.497   0.136    7   -10.015     1  ...          0.000454
# 4789         0.463   0.819    4    -7.662     1  ...          0.000268
# 4790         0.721   0.621    1    -4.378     1  ...          0.010300
#
#       liveness  valence    tempo  duration_ms  time_signature  chorus_hit  \
# 0       0.1130    0.250  179.999       231867               4    21.90591
# 1       0.5100    0.594   95.000       240213               4    30.75746
# 2       0.4950    0.485   80.021       253707               4    36.65840
# 3       0.1080    0.106  179.980       266613               4    36.05760
# 4       0.1140    0.360  138.196       257427               4    75.70191
# ...        ...      ...      ...          ...             ...         ...
# 4786    0.1030    0.175  163.993       384000               4    33.22703
# 4787    0.0888    0.553  100.975       208467               4    17.61032
# 4788    0.1140    0.236  129.628       159947               4    32.13823
# 4789    0.0599    0.591  183.998       217067               4    38.32547
# 4790    0.1990    0.568  159.967       228933               4    55.66259
#
#       sections  target                                             lyrics
# 0           12       1  [Chorus: Skylar Grey]\nWhere'd you go? I miss ...
# 1           11       1  [Intro]\nPut 'em up\nPut 'em up, put 'em up, p...
# 2           12       1  [Chorus]\nThis is why I'm hot (Hot!), this is ...
# 3           12       0  Give up! Give in!\nGive up to the light\nRespe...
# 4            8       1  Oh!\nAy baby, weh you ah deal with?\nWe come t...
# ...        ...     ...                                                ...
# 4786        19       0  [Intro: sampled]\nYou know I care for you\nYou...
# 4787        10       1  [Verse 1]\nI backed my car into a cop car the ...
# 4788         8       0  [Verse: Kate Monster]\nThere's a fine, fine li...
# 4789         8       1  [Verse 1]\nMy old friend, I recall\nThe times ...
# 4790        12       1  [Chorus]\nSittin' sideways, paused in a daze\n...
#
# [4791 rows x 22 columns]

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                        track  \
# 0           0             0               Where'd You Go
# 1           1             1                     Hands Up
# 2           3             3          This Is Why I'm Hot
# 3           4             4  Eclipse (Corona Of The Sun)
# 4           5             5                   Need U Bad
#
#                              artist                                   uri  \
# 0  Fort Minor Featuring Holly Brook  spotify:track:7pAT4dOUzjq8Ziap5ShIqC
# 1     Lloyd Banks Featuring 50 Cent  spotify:track:2GlhJyZRWP3MnSXOvnovIa
# 2                              Mims  spotify:track:0AA6zq5ArZ1sSH7VIMi4NK
# 3                         Dol Ammad  spotify:track:2nu1wORaGp31BD50qgkmw9
# 4                  Jazmine Sullivan  spotify:track:0Ri0LzOMJmqi9HGZE5cRYV
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.684   0.819    1    -3.309     0       0.2380      0.262000
# 1         0.799   0.878    1    -2.282     1       0.2190      0.077000
# 2         0.621   0.600    8    -6.349     1       0.5760      0.277000
# 3         0.395   0.820   10    -7.543     0       0.0754      0.000091
# 4         0.529   0.659    7    -5.318     1       0.0629      0.023200
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.00197     0.113    0.250  179.999       231867               4
# 1           0.00000     0.510    0.594   95.000       240213               4
# 2           0.00000     0.495    0.485   80.021       253707               4
# 3           0.36100     0.108    0.106  179.980       266613               4
# 4           0.00000     0.114    0.360  138.196       257427               4
#
#    chorus_hit  sections  target  \
# 0    21.90591        12       1
# 1    30.75746        11       1
# 2    36.65840        12       1
# 3    36.05760        12       0
# 4    75.70191         8       1
#
#                                               lyrics
# 0  [Chorus: Skylar Grey]\nWhere'd you go? I miss ...
# 1  [Intro]\nPut 'em up\nPut 'em up, put 'em up, p...
# 2  [Chorus]\nThis is why I'm hot (Hot!), this is ...
# 3  Give up! Give in!\nGive up to the light\nRespe...
# 4  Oh!\nAy baby, weh you ah deal with?\nWe come t...

# %%
##take a look at null count in each column to make a decision to drop any column with many values
#there seems to be no nulls in any column values which is good - no need to prune any column
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Unnamed: 0.1        0
# track               0
# artist              0
# uri                 0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# chorus_hit          0
# sections            0
# target              0
# lyrics              0
# dtype: int64

# %%
df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1                               track  \
# 0            0             0                      Where'd You Go
# 1            1             1                            Hands Up
# 2            3             3                 This Is Why I'm Hot
# 3            4             4         Eclipse (Corona Of The Sun)
# 4            5             5                          Need U Bad
# 5            6             6                             So Gone
# 6            7             7                               Karma
# 7            8             8                     Black Bubblegum
# 8            9             9                            Ignition
# 9           10            10                       Leonard Cohen
# 10          13            13                     On The Way Down
# 11          14            14  Never Leave You - Uh Ooh, Uh Oooh!
# 12          15            15                 Parlez Moi D'argent
# 13          16            16              When The Stars Go Blue
# 14          19            19      I'm Like A Lawyer...(Me & You)
# 15          20            20                            The Echo
# 16          22            22                  Here It Goes Again
# 17          23            23                    Ancient Covenant
# 18          24            24          If Something Should Happen
# 19          25            25  Punk Boy - 2008 Remastered Version
#
#                               artist                                   uri  \
# 0   Fort Minor Featuring Holly Brook  spotify:track:7pAT4dOUzjq8Ziap5ShIqC
# 1      Lloyd Banks Featuring 50 Cent  spotify:track:2GlhJyZRWP3MnSXOvnovIa
# 2                               Mims  spotify:track:0AA6zq5ArZ1sSH7VIMi4NK
# 3                          Dol Ammad  spotify:track:2nu1wORaGp31BD50qgkmw9
# 4                   Jazmine Sullivan  spotify:track:0Ri0LzOMJmqi9HGZE5cRYV
# 5                             Monica  spotify:track:6BIcjFZIVDZxNAcofRFPx4
# 6        Lloyd Banks Featuring Avant  spotify:track:25YwwruYRtxe6RQdKtrZFS
# 7          The Dillinger Escape Plan  spotify:track:10d9HLkpBvtWf5uhZeoSJE
# 8                           R. Kelly  spotify:track:5dNfHmqgr128gMY2tc5CeJ
# 9                   The Dreadnoughts  spotify:track:6nnOh3bassBjogelOsqS7m
# 10                      Ryan Cabrera  spotify:track:1GwVi2ceNb8dMFA3DZGnnY
# 11                           Lumidee  spotify:track:7z8aFQ2vr0fbdkuWBH3e6V
# 12                        Metal Boys  spotify:track:63t8GrQFqa4pbtTdX8DQap
# 13                        Tim McGraw  spotify:track:2R0eqSxBNxlKmfLjAwaj0C
# 14                      Fall Out Boy  spotify:track:6A9nyMBdNUzVcFHZUEZ71F
# 15                 Voxhaul Broadcast  spotify:track:3FFVYcZ1J8cPSXcoTz9Lle
# 16                             OK Go  spotify:track:1pHP4JeQV9wDx87D6qH9hD
# 17                      The Faceless  spotify:track:7uURchPesQ7LpHA4knDWB1
# 18                     Darryl Worley  spotify:track:28ZUoSyOdNswEdokyJs07B
# 19                               Ash  spotify:track:6OIcMmWwh2fmBvVccm8CbV
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.684   0.819    1    -3.309     0       0.2380      0.262000
# 1          0.799   0.878    1    -2.282     1       0.2190      0.077000
# 2          0.621   0.600    8    -6.349     1       0.5760      0.277000
# 3          0.395   0.820   10    -7.543     0       0.0754      0.000091
# 4          0.529   0.659    7    -5.318     1       0.0629      0.023200
# 5          0.618   0.552    8    -6.863     1       0.0981      0.176000
# 6          0.605   0.829   10    -2.377     0       0.4440      0.039200
# 7          0.603   0.972    8    -2.695     1       0.1410      0.006950
# 8          0.795   0.523    1    -7.165     1       0.0423      0.061000
# 9          0.316   0.977    6    -3.315     0       0.0834      0.000194
# 10         0.500   0.845    1    -5.015     1       0.0369      0.001840
# 11         0.836   0.842    4    -3.790     0       0.0525      0.026900
# 12         0.731   0.497    0   -14.406     0       0.0411      0.001860
# 13         0.445   0.682   10    -6.686     1       0.0289      0.357000
# 14         0.529   0.800    1    -3.790     1       0.0318      0.003010
# 15         0.471   0.623    1    -5.299     0       0.0344      0.203000
# 16         0.537   0.882    0    -2.306     1       0.0403      0.000342
# 17         0.328   0.972    1    -4.483     1       0.2080      0.000846
# 18         0.557   0.608    4    -8.702     1       0.0377      0.276000
# 19         0.311   0.975    7    -2.430     1       0.1470      0.037900
#
#     instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.001970    0.1130    0.250  179.999       231867               4
# 1           0.000000    0.5100    0.594   95.000       240213               4
# 2           0.000000    0.4950    0.485   80.021       253707               4
# 3           0.361000    0.1080    0.106  179.980       266613               4
# 4           0.000000    0.1140    0.360  138.196       257427               4
# 5           0.000000    0.2520    0.586   81.975       242773               4
# 6           0.000000    0.1960    0.708  176.103       278533               4
# 7           0.000011    0.1170    0.313  122.012       244227               4
# 8           0.000000    0.0914    0.855  133.024       186067               4
# 9           0.001940    0.1620    0.852  100.751       255773               4
# 10          0.000000    0.1060    0.539   95.199       212045               4
# 11          0.121000    0.0781    0.722   99.990       192427               4
# 12          0.000000    0.0904    0.427  136.981       130280               4
# 13          0.000007    0.1090    0.631  181.640       235280               4
# 14          0.000012    0.1020    0.498   96.810       211720               4
# 15          0.000000    0.1080    0.562  136.201       197200               4
# 16          0.000091    0.1200    0.810  145.729       179813               4
# 17          0.538000    0.6170    0.225  125.158       241387               4
# 18          0.000002    0.0718    0.282  159.068       279560               4
# 19          0.000000    0.3360    0.658  185.227       125747               4
#
#     chorus_hit  sections  target  \
# 0     21.90591        12       1
# 1     30.75746        11       1
# 2     36.65840        12       1
# 3     36.05760        12       0
# 4     75.70191         8       1
# 5     34.58799        11       1
# 6     29.57812        14       1
# 7     40.13441        10       0
# 8     52.70861         9       1
# 9     37.20318        10       0
# 10    31.32422        11       1
# 11    68.45976         9       1
# 12    43.87494         7       0
# 13    41.90124         9       1
# 14    62.42293         6       1
# 15    17.31815         8       0
# 16    27.11566         7       1
# 17    59.70421         8       0
# 18    43.77777        11       1
# 19    15.77112         9       0
#
#                                                lyrics
# 0   [Chorus: Skylar Grey]\nWhere'd you go? I miss ...
# 1   [Intro]\nPut 'em up\nPut 'em up, put 'em up, p...
# 2   [Chorus]\nThis is why I'm hot (Hot!), this is ...
# 3   Give up! Give in!\nGive up to the light\nRespe...
# 4   Oh!\nAy baby, weh you ah deal with?\nWe come t...
# 5   [Intro]\nSo gone over you, you, you, you\nYeah...
# 6   [Avant]\nOoh, ooh, ooh, aw yeah\nOoh, ooh, ooh...
# 7   [Verse 1]\nGot so much salt from your lies pou...
# 8   [Intro]\nYou remind me of something\nI just ca...
# 9   [Verse 1]\nWell you're living in disgrace, now...
# 10  [Verse]\nSick and tired of this world\nThere's...
# 11  [Intro: Oswin Benjamin]\nYeah\nI want to\nWake...
# 12  Avant-propos :[Couplet 1 : Shurik'n]\nRegarde ...
# 13  [Verse 1]\nDancin' when the stars go blue\nDan...
# 14  [Verse 1]\nLast year's wishes are this year's ...
# 15  [Verse 1]\nEverybody's talking about the echo\...
# 16  [Verse 1]\nIt could be ten, but then again I c...
# 17  A treaty between alpha and omega beings\nSummo...
# 18  Buddy you and me go way back\nCamp Lejeune, al...
# 19  Calendrier 2021JANFÉVMARAVRMAIJUNJULAOÛSEPOCTN...

# %%
#take a look at data types of each column before making any conversion of a feature/column data type
df.dtypes
# Out:
# Unnamed: 0            int64
# Unnamed: 0.1          int64
# track                object
# artist               object
# uri                  object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# chorus_hit          float64
# sections              int64
# target                int64
# lyrics               object
# dtype: object

# %%
#convert the data type of 'track' and artist features from 'object' to string
df['track'] = df['track'].astype(str)
df['artist'] = df['artist'].astype(str)

# %%
sns.countplot(y="track", data=df,
              order=df.track.value_counts().iloc[:20].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='track'>

# %%
sns.countplot(y="track", data=df,
              order=df.track.value_counts().iloc[:20].index)
#the graph indicates ther are duplicate tracks
# Out:
# <AxesSubplot:xlabel='count', ylabel='track'>

# %%
#the target column is nothing but popularity/hit feature with values of 0 or 1 indicateing flop or hit
sns.countplot(y="target", data=df,
              order=df.target.value_counts().iloc[:20].index)
#the output graph indicates there are almost equal hits and flops and hence is an even data set
# Out:
# <AxesSubplot:xlabel='count', ylabel='target'>

# %%
#Lets have a look at distribution based on acoustic features using histograms

f, axes = plt.subplots(3, 5, figsize=(12, 12))
sns.distplot( df["danceability"] , color="teal", ax=axes[0, 0])
sns.distplot( df["energy"] , color="teal", ax=axes[0, 1])
sns.distplot( df["key"] , color="teal", ax=axes[0, 2])
sns.distplot( df["loudness"] , color="teal", ax=axes[0, 3])
sns.distplot( df["mode"] , color="teal", ax=axes[0, 4])
sns.distplot( df["speechiness"] , color="teal", ax=axes[1, 0])
sns.distplot( df["acousticness"] , color="teal", ax=axes[1, 1])
sns.distplot( df["instrumentalness"] , color="teal", ax=axes[1, 2])
sns.distplot( df["liveness"] , color="teal", ax=axes[1, 3])
sns.distplot( df["valence"] , color="teal", ax=axes[1, 4])
sns.distplot( df["tempo"] , color="teal", ax=axes[2, 0])
sns.distplot( df["duration_ms"] , color="teal", ax=axes[2, 1])
sns.distplot( df["time_signature"] , color="teal", ax=axes[2, 2])
sns.distplot( df["chorus_hit"] , color="teal", ax=axes[2, 3])

f.delaxes(axes[2][4])
plt.show()
# Out:
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rama/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
